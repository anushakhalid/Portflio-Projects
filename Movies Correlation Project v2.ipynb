# %%
#  importing the packages 
import pandas as pd
import numpy as np
import seaborn as sns
import numpy  as np

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
df=pd.read_csv("movies.csv")

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
#checking missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
##Handling missing values
df=df.dropna()
# Out:
# name - 0.0%
# rating - 1.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 28.0%
# gross - 2.0%
# company - 0.0%
# runtime - 0.0%

# %%
#data types for columns
df.dtypes
##Converting data types
df['budget']=df['budget'].astype('int64')
df['gross']=df['gross'].astype('int64')

# %%
#create  correct year column
df['CorrectYear']=df['released'].astype(str).str[8:13]

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime CorrectYear
# 0   46998772        Warner Bros.    146.0        1980
# 1   58853106   Columbia Pictures    104.0       1980
# 2  538375067           Lucasfilm    124.0        1980
# 3   83453539  Paramount Pictures     88.0       1980
# 4   39846344      Orion Pictures     98.0        1980

# %%
df.dtypes
# Out:
# name            object
# rating          object
# genre           object
# year             int64
# released        object
# score          float64
# votes          float64
# director        object
# writer          object
# star            object
# country         object
# budget           int64
# gross            int64
# company         object
# runtime        float64
# CorrectYear     object
# dtype: object

# %%
df=df.sort_values(by=['gross'],inplace=False,ascending=True)

# %%
pd.set_option('display.max_rows',None)

# %%
#Drop Duplicates
df.drop_duplicates().head()
# Out:
#                             name     rating   genre  year  \
# 3203                  Trojan War      PG-13  Comedy  1997
# 272                     Parasite          R  Horror  1982
# 3681                Ginger Snaps  Not Rated   Drama  2000
# 2434  Philadelphia Experiment II      PG-13  Action  1993
# 5640                 Tanner Hall          R   Drama  2009
#
#                             released  score    votes             director  \
# 3203        October 1, 1997 (Brazil)    5.7   5800.0         George Huang
# 272   March 12, 1982 (United States)    3.9   2300.0         Charles Band
# 3681           May 11, 2001 (Canada)    6.8  43000.0         John Fawcett
# 2434      June 4, 1994 (South Korea)    4.5   1900.0     Stephen Cornwell
# 5640       January 15, 2015 (Sweden)    5.8   3500.0  Francesca Gregorini
#
#                        writer             star        country    budget  \
# 3203                Andy Burg     Will Friedle  United States  15000000
# 272             Alan J. Adler  Robert Glaudini  United States    800000
# 3681             Karen Walton    Emily Perkins         Canada   5000000
# 2434       Wallace C. Bennett     Brad Johnson  United States   5000000
# 5640  Tatiana von Fürstenberg      Rooney Mara  United States   3000000
#
#       gross                    company  runtime CorrectYear
# 3203    309                   Daybreak     85.0       1, 19
# 272    2270           Embassy Pictures     85.0       , 198
# 3681   2554  Copperheart Entertainment    108.0       2001
# 2434   2970           Trimark Pictures     97.0       1994
# 5640   5073           Two Prong Lesson     96.0       15, 2

# %%
#Scatter plot with budget vs Revenue
plt.scatter(x=df['budget'],y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Budget for Film')
plt.ylabel('Gross Earnings')
plt.show()

# %%
#Plot the budget vs gross using Seaborn
sns.regplot(x='budget',y='gross',data=df,scatter_kws={"color":"red"},line_kws={"color":"blue"})

# %%
#Correlation Matrix
df.corr()#pearson,knedall,spearman
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
df.corr(method='kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.039389  0.296512  0.220833  0.239539  0.064824
# score    0.039389  1.000000  0.350185 -0.006406  0.124943  0.292254
# votes    0.296512  0.350185  1.000000  0.346274  0.553625  0.205344
# budget   0.220833 -0.006406  0.346274  1.000000  0.512057  0.231278
# gross    0.239539  0.124943  0.553625  0.512057  1.000000  0.176979
# runtime  0.064824  0.292254  0.205344  0.231278  0.176979  1.000000

# %%
df.corr(method='spearman')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.057741  0.427623  0.312886  0.351045  0.095444
# score    0.057741  1.000000  0.495409 -0.009971  0.183192  0.412155
# votes    0.427623  0.495409  1.000000  0.493461  0.745793  0.300621
# budget   0.312886 -0.009971  0.493461  1.000000  0.692958  0.330794
# gross    0.351045  0.183192  0.745793  0.692958  1.000000  0.257400
# runtime  0.095444  0.412155  0.300621  0.330794  0.257400  1.000000

# %%
correlation_matrix=df.corr(method='pearson')
sns.heatmap(correlation_matrix,annot=True)
plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
#Company
df.head()
# Out:
#                             name     rating   genre  year  \
# 3203                  Trojan War      PG-13  Comedy  1997
# 272                     Parasite          R  Horror  1982
# 3681                Ginger Snaps  Not Rated   Drama  2000
# 2434  Philadelphia Experiment II      PG-13  Action  1993
# 5640                 Tanner Hall          R   Drama  2009
#
#                             released  score    votes             director  \
# 3203        October 1, 1997 (Brazil)    5.7   5800.0         George Huang
# 272   March 12, 1982 (United States)    3.9   2300.0         Charles Band
# 3681           May 11, 2001 (Canada)    6.8  43000.0         John Fawcett
# 2434      June 4, 1994 (South Korea)    4.5   1900.0     Stephen Cornwell
# 5640       January 15, 2015 (Sweden)    5.8   3500.0  Francesca Gregorini
#
#                        writer             star        country    budget  \
# 3203                Andy Burg     Will Friedle  United States  15000000
# 272             Alan J. Adler  Robert Glaudini  United States    800000
# 3681             Karen Walton    Emily Perkins         Canada   5000000
# 2434       Wallace C. Bennett     Brad Johnson  United States   5000000
# 5640  Tatiana von Fürstenberg      Rooney Mara  United States   3000000
#
#       gross                    company  runtime CorrectYear
# 3203    309                   Daybreak     85.0       1, 19
# 272    2270           Embassy Pictures     85.0       , 198
# 3681   2554  Copperheart Entertainment    108.0       2001
# 2434   2970           Trimark Pictures     97.0       1994
# 5640   5073           Two Prong Lesson     96.0       15, 2

# %%
df_numerized=df
for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype=='object'):
        df_numerized[col_name]=df_numerized[col_name].astype('category')
        df_numerized[col_name]=df_numerized[col_name].cat.codes
df_numerized.head()
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 3203  4966       5      4  1997      2152    5.7   5800.0       651     161
# 272   2909       6      9  1982      1525    3.9   2300.0       261      55
# 3681  1595       3      6  2000      1721    6.8  43000.0       952    1683
# 2434  2969       5      0  1993      1467    4.5   1900.0      1805    3102
# 5640  3794       6      6  2009       890    5.8   3500.0       585    2924
#
#       star  country    budget  gross  company  runtime  CorrectYear
# 3203  1811       47  15000000    309      504     85.0          106
# 272   1473       47    800000   2270      582     85.0           80
# 3681   527        6   5000000   2554      466    108.0          153
# 2434   186       47   5000000   2970     1376     97.0          142
# 5640  1498       47   3000000   5073     1385     96.0          119

# %%
correlation_matrix=df_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix,annot=True)
plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
df_numerized.corr().head()
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating   -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre     0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year      0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
#
#              votes  director    writer      star   country    budget  \
# name      0.012615  0.015246  0.012880 -0.006882 -0.025490  0.023392
# rating    0.006031  0.014656 -0.003149  0.009196  0.008230 -0.203946
# genre    -0.135990 -0.008553  0.017578  0.003341 -0.009164 -0.368523
# year      0.206021 -0.038354 -0.025908 -0.032157 -0.066748  0.327722
# released  0.028833  0.002308  0.008072  0.015706 -0.017228  0.019952
#
#              gross   company   runtime  CorrectYear
# name      0.005639  0.021697  0.010850    -0.012024
# rating   -0.181906 -0.092357  0.140792     0.120958
# genre    -0.244101 -0.071334 -0.059237     0.051315
# year      0.274321 -0.014333  0.075077     0.077609
# released  0.008501 -0.002407  0.008975     0.380835

# %%
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              year           0.025542
#              released      -0.006152
#              score          0.014450
#              votes          0.012615
#              director       0.015246
#              writer         0.012880
#              star          -0.006882
#              country       -0.025490
#              budget         0.023392
#              gross          0.005639
#              company        0.021697
#              runtime        0.010850
#              CorrectYear   -0.012024
# rating       name          -0.029234
#              rating         1.000000
#              genre          0.147796
#              year           0.019499
#              released       0.018083
#              score          0.065983
#              votes          0.006031
#              director       0.014656
#              writer        -0.003149
#              star           0.009196
#              country        0.008230
#              budget        -0.203946
#              gross         -0.181906
#              company       -0.092357
#              runtime        0.140792
#              CorrectYear    0.120958
# genre        name           0.010996
#              rating         0.147796
#              genre          1.000000
#              year          -0.073167
#              released       0.022142
#              score          0.035106
#              votes         -0.135990
#              director      -0.008553
#              writer         0.017578
#              star           0.003341
#              country       -0.009164
#              budget        -0.368523
#              gross         -0.244101
#              company       -0.071334
#              runtime       -0.059237
#              CorrectYear    0.051315
# year         name           0.025542
#              rating         0.019499
#              genre         -0.073167
#              year           1.000000
#              released      -0.001740
#              score          0.056386
#              votes          0.206021
#              director      -0.038354
#              writer        -0.025908
#              star          -0.032157
#              country       -0.066748
#              budget         0.327722
#              gross          0.274321
#              company       -0.014333
#              runtime        0.075077
#              CorrectYear    0.077609
# released     name          -0.006152
#              rating         0.018083
#              genre          0.022142
#              year          -0.001740
#              released       1.000000
#              score          0.045874
#              votes          0.028833
#              director       0.002308
#              writer         0.008072
#              star           0.015706
#              country       -0.017228
#              budget         0.019952
#              gross          0.008501
#              company       -0.002407
#              runtime        0.008975
#              CorrectYear    0.380835
# score        name           0.014450
#              rating         0.065983
#              genre          0.035106
#              year           0.056386
#              released       0.045874
#              score          1.000000
#              votes          0.474256
#              director       0.005413
#              writer         0.012843
#              star           0.007296
#              country       -0.043051
#              budget         0.072001
#              gross          0.222556
#              company        0.020656
#              runtime        0.414068
#              CorrectYear   -0.020251
# votes        name           0.012615
#              rating         0.006031
#              genre         -0.135990
#              year           0.206021
#              released       0.028833
#              score          0.474256
#              votes          1.000000
#              director      -0.010376
#              writer        -0.005316
#              star          -0.017638
#              country        0.041551
#              budget         0.439675
#              gross          0.614751
#              company        0.118470
#              runtime        0.352303
#              CorrectYear   -0.060276
# director     name           0.015246
#              rating         0.014656
#              genre         -0.008553
#              year          -0.038354
#              released       0.002308
#              score          0.005413
#              votes         -0.010376
#              director       1.000000
#              writer         0.261735
#              star           0.036593
#              country        0.011133
#              budget        -0.009662
#              gross         -0.029560
#              company       -0.008223
#              runtime        0.017433
#              CorrectYear   -0.002020
# writer       name           0.012880
#              rating        -0.003149
#              genre          0.017578
#              year          -0.025908
#              released       0.008072
#              score          0.012843
#              votes         -0.005316
#              director       0.261735
#              writer         1.000000
#              star           0.018520
#              country        0.022488
#              budget        -0.039466
#              gross         -0.035885
#              company       -0.003697
#              runtime       -0.017561
#              CorrectYear    0.010132
# star         name          -0.006882
#              rating         0.009196
#              genre          0.003341
#              year          -0.032157
#              released       0.015706
#              score          0.007296
#              votes         -0.017638
#              director       0.036593
#              writer         0.018520
#              star           1.000000
#              country       -0.009990
#              budget        -0.021473
#              gross         -0.000004
#              company        0.014082
#              runtime        0.010108
#              CorrectYear    0.025947
# country      name          -0.025490
#              rating         0.008230
#              genre         -0.009164
#              year          -0.066748
#              released      -0.017228
#              score         -0.043051
#              votes          0.041551
#              director       0.011133
#              writer         0.022488
#              star          -0.009990
#              country        1.000000
#              budget         0.052977
#              gross          0.060078
#              company        0.048569
#              runtime       -0.034477
#              CorrectYear   -0.042842
# budget       name           0.023392
#              rating        -0.203946
#              genre         -0.368523
#              year           0.327722
#              released       0.019952
#              score          0.072001
#              votes          0.439675
#              director      -0.009662
#              writer        -0.039466
#              star          -0.021473
#              country        0.052977
#              budget         1.000000
#              gross          0.740247
#              company        0.170235
#              runtime        0.318695
#              CorrectYear   -0.110161
# gross        name           0.005639
#              rating        -0.181906
#              genre         -0.244101
#              year           0.274321
#              released       0.008501
#              score          0.222556
#              votes          0.614751
#              director      -0.029560
#              writer        -0.035885
#              star          -0.000004
#              country        0.060078
#              budget         0.740247
#              gross          1.000000
#              company        0.149553
#              runtime        0.275796
#              CorrectYear   -0.106301
# company      name           0.021697
#              rating        -0.092357
#              genre         -0.071334
#              year          -0.014333
#              released      -0.002407
#              score          0.020656
#              votes          0.118470
#              director      -0.008223
#              writer        -0.003697
#              star           0.014082
#              country        0.048569
#              budget         0.170235
#              gross          0.149553
#              company        1.000000
#              runtime        0.037585
#              CorrectYear   -0.044111
# runtime      name           0.010850
#              rating         0.140792
#              genre         -0.059237
#              year           0.075077
#              released       0.008975
#              score          0.414068
#              votes          0.352303
#              director       0.017433
#              writer        -0.017561
#              star           0.010108
#              country       -0.034477
#              budget         0.318695
#              gross          0.275796
#              company        0.037585
#              runtime        1.000000
#              CorrectYear   -0.036898
# CorrectYear  name          -0.012024
#              rating         0.120958
#              genre          0.051315
#              year           0.077609
#              released       0.380835
#              score         -0.020251
#              votes         -0.060276
#              director      -0.002020
#              writer         0.010132
#              star           0.025947
#              country       -0.042842
#              budget        -0.110161
#              gross         -0.106301
#              company       -0.044111
#              runtime       -0.036898
#              CorrectYear    1.000000
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# budget       genre         -0.368523
# genre        budget        -0.368523
#              gross         -0.244101
# gross        genre         -0.244101
# budget       rating        -0.203946
# rating       budget        -0.203946
# gross        rating        -0.181906
# rating       gross         -0.181906
# votes        genre         -0.135990
# genre        votes         -0.135990
# budget       CorrectYear   -0.110161
# CorrectYear  budget        -0.110161
# gross        CorrectYear   -0.106301
# CorrectYear  gross         -0.106301
# rating       company       -0.092357
# company      rating        -0.092357
# genre        year          -0.073167
# year         genre         -0.073167
# company      genre         -0.071334
# genre        company       -0.071334
# year         country       -0.066748
# country      year          -0.066748
# CorrectYear  votes         -0.060276
# votes        CorrectYear   -0.060276
# runtime      genre         -0.059237
# genre        runtime       -0.059237
# CorrectYear  company       -0.044111
# company      CorrectYear   -0.044111
# country      score         -0.043051
# score        country       -0.043051
# CorrectYear  country       -0.042842
# country      CorrectYear   -0.042842
# writer       budget        -0.039466
# budget       writer        -0.039466
# year         director      -0.038354
# director     year          -0.038354
# CorrectYear  runtime       -0.036898
# runtime      CorrectYear   -0.036898
# writer       gross         -0.035885
# gross        writer        -0.035885
# runtime      country       -0.034477
# country      runtime       -0.034477
# star         year          -0.032157
# year         star          -0.032157
# director     gross         -0.029560
# gross        director      -0.029560
# name         rating        -0.029234
# rating       name          -0.029234
# writer       year          -0.025908
# year         writer        -0.025908
# country      name          -0.025490
# name         country       -0.025490
# star         budget        -0.021473
# budget       star          -0.021473
# score        CorrectYear   -0.020251
# CorrectYear  score         -0.020251
# votes        star          -0.017638
# star         votes         -0.017638
# writer       runtime       -0.017561
# runtime      writer        -0.017561
# country      released      -0.017228
# released     country       -0.017228
# year         company       -0.014333
# company      year          -0.014333
# name         CorrectYear   -0.012024
# CorrectYear  name          -0.012024
# votes        director      -0.010376
# director     votes         -0.010376
# country      star          -0.009990
# star         country       -0.009990
# budget       director      -0.009662
# director     budget        -0.009662
# genre        country       -0.009164
# country      genre         -0.009164
# genre        director      -0.008553
# director     genre         -0.008553
# company      director      -0.008223
# director     company       -0.008223
# star         name          -0.006882
# name         star          -0.006882
#              released      -0.006152
# released     name          -0.006152
# votes        writer        -0.005316
# writer       votes         -0.005316
#              company       -0.003697
# company      writer        -0.003697
# writer       rating        -0.003149
# rating       writer        -0.003149
# released     company       -0.002407
# company      released      -0.002407
# director     CorrectYear   -0.002020
# CorrectYear  director      -0.002020
# year         released      -0.001740
# released     year          -0.001740
# gross        star          -0.000004
# star         gross         -0.000004
# released     director       0.002308
# director     released       0.002308
# genre        star           0.003341
# star         genre          0.003341
# score        director       0.005413
# director     score          0.005413
# gross        name           0.005639
# name         gross          0.005639
# votes        rating         0.006031
# rating       votes          0.006031
# star         score          0.007296
# score        star           0.007296
# released     writer         0.008072
# writer       released       0.008072
# rating       country        0.008230
# country      rating         0.008230
# released     gross          0.008501
# gross        released       0.008501
# released     runtime        0.008975
# runtime      released       0.008975
# rating       star           0.009196
# star         rating         0.009196
# runtime      star           0.010108
# star         runtime        0.010108
# CorrectYear  writer         0.010132
# writer       CorrectYear    0.010132
# runtime      name           0.010850
# name         runtime        0.010850
# genre        name           0.010996
# name         genre          0.010996
# director     country        0.011133
# country      director       0.011133
# name         votes          0.012615
# votes        name           0.012615
# score        writer         0.012843
# writer       score          0.012843
# name         writer         0.012880
# writer       name           0.012880
# company      star           0.014082
# star         company        0.014082
# score        name           0.014450
# name         score          0.014450
# rating       director       0.014656
# director     rating         0.014656
# name         director       0.015246
# director     name           0.015246
# released     star           0.015706
# star         released       0.015706
# runtime      director       0.017433
# director     runtime        0.017433
# genre        writer         0.017578
# writer       genre          0.017578
# released     rating         0.018083
# rating       released       0.018083
# star         writer         0.018520
# writer       star           0.018520
# year         rating         0.019499
# rating       year           0.019499
# budget       released       0.019952
# released     budget         0.019952
# score        company        0.020656
# company      score          0.020656
# name         company        0.021697
# company      name           0.021697
# genre        released       0.022142
# released     genre          0.022142
# writer       country        0.022488
# country      writer         0.022488
# budget       name           0.023392
# name         budget         0.023392
# year         name           0.025542
# name         year           0.025542
# star         CorrectYear    0.025947
# CorrectYear  star           0.025947
# released     votes          0.028833
# votes        released       0.028833
# genre        score          0.035106
# score        genre          0.035106
# star         director       0.036593
# director     star           0.036593
# company      runtime        0.037585
# runtime      company        0.037585
# votes        country        0.041551
# country      votes          0.041551
# score        released       0.045874
# released     score          0.045874
# country      company        0.048569
# company      country        0.048569
# genre        CorrectYear    0.051315
# CorrectYear  genre          0.051315
# country      budget         0.052977
# budget       country        0.052977
# score        year           0.056386
# year         score          0.056386
# country      gross          0.060078
# gross        country        0.060078
# score        rating         0.065983
# rating       score          0.065983
# score        budget         0.072001
# budget       score          0.072001
# year         runtime        0.075077
# runtime      year           0.075077
# year         CorrectYear    0.077609
# CorrectYear  year           0.077609
# company      votes          0.118470
# votes        company        0.118470
# CorrectYear  rating         0.120958
# rating       CorrectYear    0.120958
# runtime      rating         0.140792
# rating       runtime        0.140792
# genre        rating         0.147796
# rating       genre          0.147796
# gross        company        0.149553
# company      gross          0.149553
# budget       company        0.170235
# company      budget         0.170235
# year         votes          0.206021
# votes        year           0.206021
# score        gross          0.222556
# gross        score          0.222556
# director     writer         0.261735
# writer       director       0.261735
# gross        year           0.274321
# year         gross          0.274321
# runtime      gross          0.275796
# gross        runtime        0.275796
# runtime      budget         0.318695
# budget       runtime        0.318695
# year         budget         0.327722
# budget       year           0.327722
# votes        runtime        0.352303
# runtime      votes          0.352303
# CorrectYear  released       0.380835
# released     CorrectYear    0.380835
# score        runtime        0.414068
# runtime      score          0.414068
# votes        budget         0.439675
# budget       votes          0.439675
# votes        score          0.474256
# score        votes          0.474256
# gross        votes          0.614751
# votes        gross          0.614751
# gross        budget         0.740247
# budget       gross          0.740247
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# CorrectYear  CorrectYear    1.000000
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# gross        votes          0.614751
# votes        gross          0.614751
# gross        budget         0.740247
# budget       gross          0.740247
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# CorrectYear  CorrectYear    1.000000
# dtype: float64

# %%
#Result
#Votes and Budget have the highest correlation  to gross earnings
#Company has low correlation
